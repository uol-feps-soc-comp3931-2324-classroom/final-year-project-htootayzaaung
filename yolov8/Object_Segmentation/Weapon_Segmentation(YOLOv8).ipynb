# %%
# !nvidia-smi
# Out:
# Mon May  6 17:59:54 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0              24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
# !pip install gdown

# %%
# Download the file using gdown
import gdown

# Update the file ID from the new URL provided
file_id = '19donSYg4SspV-jLBOO7cqFgWsf1KyLut'

# Construct the Google Drive download URL
download_url = f'https://drive.google.com/uc?id={file_id}'

# Download and save the file locally (adjust the output filename if needed)
output = 'Weapon_Segmentation.zip'
gdown.download(download_url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=19donSYg4SspV-jLBOO7cqFgWsf1KyLut
# From (redirected): https://drive.google.com/uc?id=19donSYg4SspV-jLBOO7cqFgWsf1KyLut&confirm=t&uuid=166ebc3e-c11d-4b3b-80e8-f607fb25c67f
# To: /content/Weapon_Segmentation.zip
#
#   0%|          | 0.00/237M [00:00<?, ?B/s]
#   2%|▏         | 4.72M/237M [00:00<00:34, 6.84MB/s]
#   7%|▋         | 17.3M/237M [00:01<00:16, 13.1MB/s]
#  14%|█▍        | 34.1M/237M [00:02<00:11, 18.2MB/s]
#  20%|█▉        | 47.2M/237M [00:02<00:06, 27.8MB/s]
#  23%|██▎       | 53.5M/237M [00:02<00:08, 20.7MB/s]
#  25%|██▍       | 59.2M/237M [00:02<00:07, 23.4MB/s]
#  28%|██▊       | 67.6M/237M [00:03<00:08, 19.9MB/s]
#  32%|███▏      | 76.0M/237M [00:03<00:06, 25.5MB/s]
#  36%|███▌      | 84.4M/237M [00:04<00:07, 20.3MB/s]
#  39%|███▉      | 92.8M/237M [00:04<00:05, 26.1MB/s]
#  43%|████▎     | 101M/237M [00:04<00:06, 21.1MB/s]
#  47%|████▋     | 111M/237M [00:04<00:04, 28.3MB/s]
# ...

# %%
# !unzip -q Weapon_Segmentation.zip -d .

# %%
# !pwd
# Out:
# /content

# %%
# %cd Weapon_Segmentation/
# Out:
# /content/Weapon_Segmentation

# %%
# !ls
# Out:
# data_custom.yaml  README.dataset.txt  README.roboflow.txt  test  train	train.py  val

# %%
# !python3 train.py
# Out:
# Starting training with command: yolo task=segment mode=train epochs=75 data=data_custom.yaml model=yolov8m-seg.pt imgsz=640 batch=8
# ...
# 100% 52.4M/52.4M [00:00<00:00, 66.5MB/s]
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt conf=0.25 source=test/images
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27224121 parameters, 0 gradients, 110.0 GFLOPs
#
# image 1/188 /content/Weapon_Segmentation/test/images/1014_jpg.rf.fd987b3c771cedec550b7f27d76df1af.jpg: 640x640 1 Gun, 10.1ms
# image 2/188 /content/Weapon_Segmentation/test/images/101_jpg.rf.16908c82e05c877ca5a3045916cd31a7.jpg: 640x640 1 Axe, 10.5ms
# image 3/188 /content/Weapon_Segmentation/test/images/1023_jpg.rf.e4e5fe6e70236045274dde4b5b2c253b.jpg: 640x640 1 Knife, 9.9ms
# image 4/188 /content/Weapon_Segmentation/test/images/1037_jpg.rf.6d95e7cb0cabd86555c2b6d01c488fd0.jpg: 640x640 5 Guns, 10.4ms
# image 5/188 /content/Weapon_Segmentation/test/images/1059_jpg.rf.cbf8f41da349a7339b64e6abc8440894.jpg: 640x640 1 Gun, 1 Knife, 9.9ms
# image 6/188 /content/Weapon_Segmentation/test/images/1069_jpg.rf.c788f965646a3b88563c3599b227ca2f.jpg: 640x640 1 Gun, 9.9ms
# ...

# %%
# !zip -r runs runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/segment/ (stored 0%)
#   adding: runs/segment/train/ (stored 0%)
#   adding: runs/segment/train/MaskR_curve.png (deflated 13%)
#   adding: runs/segment/train/val_batch0_pred.jpg (deflated 7%)
#   adding: runs/segment/train/BoxP_curve.png (deflated 12%)
#   adding: runs/segment/train/val_batch0_labels.jpg (deflated 7%)
#   adding: runs/segment/train/train_batch32047.jpg (deflated 9%)
#   adding: runs/segment/train/weights/ (stored 0%)
#   adding: runs/segment/train/weights/last.pt (deflated 8%)
#   adding: runs/segment/train/weights/best.pt (deflated 8%)
#   adding: runs/segment/train/results.png (deflated 8%)
#   adding: runs/segment/train/train_batch32046.jpg (deflated 6%)
#   adding: runs/segment/train/val_batch2_pred.jpg (deflated 8%)
#   adding: runs/segment/train/confusion_matrix_normalized.png (deflated 28%)
#   adding: runs/segment/train/train_batch2.jpg (deflated 4%)
# ...
