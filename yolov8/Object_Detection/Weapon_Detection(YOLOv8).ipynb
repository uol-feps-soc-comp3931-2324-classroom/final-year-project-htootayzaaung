# %%
# !nvidia-smi
# Out:
# Tue May  7 08:04:12 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0              25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 kB 10.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !pip install gdown

# %%
# Import gdown for downloading the file
import gdown

# New file ID extracted from the latest link provided
file_id = '1apb6_CRX29mqTBmPtROTANikG4O_zye6'


# Create the download URL using the new file ID
download_url = f'https://drive.google.com/uc?id={file_id}'

# Download and save the file locally with the desired filename
output = 'Weapon_Detection.zip'
gdown.download(download_url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1apb6_CRX29mqTBmPtROTANikG4O_zye6
# From (redirected): https://drive.google.com/uc?id=1apb6_CRX29mqTBmPtROTANikG4O_zye6&confirm=t&uuid=56341a3c-3a51-4d6c-ba85-be20c8221ae6
# To: /content/Weapon_Detection.zip
# 100%|██████████| 245M/245M [00:03<00:00, 62.3MB/s]
# 'Weapon_Detection.zip'

# %%
# !unzip -q Weapon_Detection.zip -d .

# %%
# !pwd
# Out:
# /content

# %%
# %cd Weapon_Detection
# Out:
# /content/Weapon_Detection

# %%
# !ls
# Out:
# data_custom.yaml  README.dataset.txt  README.roboflow.txt  test  train	train.py  val

# %%
# !python3 train.py
# Out:
# Starting training with command: yolo task=detect mode=train epochs=75 data=data_custom.yaml model=yolov8m.pt imgsz=640 batch=8
# ...
# 100% 49.7M/49.7M [00:00<00:00, 334MB/s]
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=test/images
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/196 /content/Weapon_Detection/test/images/003af63a783a1615_jpg.rf.a1604da0249e644b875324c60a0021a7.jpg: 640x640 (no detections), 13.7ms
# image 2/196 /content/Weapon_Detection/test/images/0231d2f11eb7a483_jpg.rf.ab7f38f1316b341d3b58f7ee7e84beed.jpg: 640x640 1 Gun, 9.5ms
# image 3/196 /content/Weapon_Detection/test/images/0255c5b642987e73_jpg.rf.149bc300c6626152c94570d7c837a2ce.jpg: 640x640 2 Guns, 11.5ms
# image 4/196 /content/Weapon_Detection/test/images/0315e60e498caa4c_jpg.rf.9150790f9da78819fd88c41d72ca86b0.jpg: 640x640 (no detections), 14.7ms
# image 5/196 /content/Weapon_Detection/test/images/039f27ac12c793bb_jpg.rf.65eb442f3dc7816c83b0f6be617be160.jpg: 640x640 1 Gun, 13.2ms
# ...

# %%
# !zip -r runs runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/val_batch0_pred.jpg (deflated 10%)
#   adding: runs/detect/train/val_batch0_labels.jpg (deflated 10%)
#   adding: runs/detect/train/P_curve.png (deflated 10%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/weights/last.pt (deflated 8%)
#   adding: runs/detect/train/weights/best.pt (deflated 8%)
#   adding: runs/detect/train/results.png (deflated 8%)
#   adding: runs/detect/train/PR_curve.png (deflated 12%)
#   adding: runs/detect/train/val_batch2_pred.jpg (deflated 10%)
#   adding: runs/detect/train/confusion_matrix_normalized.png (deflated 29%)
#   adding: runs/detect/train/train_batch2.jpg (deflated 3%)
#   adding: runs/detect/train/val_batch2_labels.jpg (deflated 10%)
#   adding: runs/detect/train/train_batch33475.jpg (deflated 9%)
#   adding: runs/detect/train/results.csv (deflated 85%)
# ...
