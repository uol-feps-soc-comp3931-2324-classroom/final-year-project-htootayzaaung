# %%
# !nvidia-smi
# Out:
# Thu Feb 22 00:16:42 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0              25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.9/715.9 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/htootayzaaung/train.git
# !git clone https://github.com/htootayzaaung/val.git
# !git clone https://github.com/htootayzaaung/test.git
# Out:
# Cloning into 'train'...
# remote: Enumerating objects: 8058, done.
# remote: Total 8058 (delta 0), reused 0 (delta 0), pack-reused 8058
# Receiving objects: 100% (8058/8058), 201.52 MiB | 25.05 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (8236/8236), done.
# Cloning into 'val'...
# remote: Enumerating objects: 788, done.
# remote: Counting objects: 100% (788/788), done.
# remote: Compressing objects: 100% (450/450), done.
# remote: Total 788 (delta 1), reused 788 (delta 1), pack-reused 0
# Receiving objects: 100% (788/788), 19.68 MiB | 21.95 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Cloning into 'test'...
# remote: Enumerating objects: 396, done.
# remote: Counting objects: 100% (396/396), done.
# remote: Compressing objects: 100% (225/225), done.
# remote: Total 396 (delta 1), reused 396 (delta 1), pack-reused 0
# Receiving objects: 100% (396/396), 9.99 MiB | 19.74 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !pwd
# !ls
# %cd test/images
# !ls -1 *.jpg | wc -l
# Out:
# /content
# data_custom.yaml  sample_data  test  train  train.py  val
# /content/test/images
# 196

# %%
# %cd ../../test/labels
# !ls -1 *.txt | wc -l
# Out:
# /content/test/labels
# 196

# %%
# %cd ../../train/images
# !ls -1 *.jpg | wc -l
# Out:
# /content/train/images
# 4118

# %%
# %cd ../../train/labels
# !ls -1 *.txt | wc -l
# Out:
# /content/train/labels
# 4118

# %%
# %cd ../../val/images
# !ls -1 *.jpg | wc -l
# Out:
# /content/val/images
# 392

# %%
# %cd ../../val/labels
# !ls -1 *.txt | wc -l
# Out:
# /content/val/labels
# 392

# %%
# %cd ../../
# !pwd
# !ls
# Out:
# /content
# /content
# data_custom.yaml  sample_data  test  train  train.py  val

# %%
#Only run this cell if the folder "runs" is not empty!
# !rm -rf runs test train val

# %%
# !ls

# %%
# !python train.py
# Out:
# Starting training with command: yolo task=detect mode=train epochs=75 data=data_custom.yaml model=yolov8m.pt imgsz=640 batch=8
# ...
# 100% 49.7M/49.7M [00:00<00:00, 61.4MB/s]
# Ultralytics YOLOv8.1.17 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !zip -r runs runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/predict/ (stored 0%)
#   adding: runs/detect/predict/8df6d0760f84982e_jpg.rf.4f941deaa851d29114ab08083a240118.jpg (deflated 12%)
#   adding: runs/detect/predict/pixabay_22_jpg.rf.df60468250724dc6d7a0570e58e675ed.jpg (deflated 6%)
#   adding: runs/detect/predict/1e35b9b3d040665a_jpg.rf.b6690914f6c12a9745872d7ff2e45ace.jpg (deflated 4%)
#   adding: runs/detect/predict/pixabay_5_jpg.rf.137d3b3ca0fdaf79d5e1f7fc0196830d.jpg (deflated 8%)
#   adding: runs/detect/predict/7c252c7fbb3273d0_jpg.rf.198d9e8a3a3cca522cb827be723ebf49.jpg (deflated 6%)
#   adding: runs/detect/predict/71db8bc3b77fe137_jpg.rf.3cb12db245f4c3daa7ecb20a90bb793e.jpg (deflated 4%)
#   adding: runs/detect/predict/d0d9c9ff6448a32d_jpg.rf.807a347069536bec7ef6a274b1523849.jpg (deflated 6%)
#   adding: runs/detect/predict/d60ec7463bbef593_jpg.rf.4e07aa1afeabd76f25e0496f784aeb8e.jpg (deflated 4%)
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=test/images
# Out:
# Ultralytics YOLOv8.1.17 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/196 /content/test/images/003af63a783a1615_jpg.rf.a1604da0249e644b875324c60a0021a7.jpg: 640x640 1 Gun, 9.3ms
# image 2/196 /content/test/images/0231d2f11eb7a483_jpg.rf.ab7f38f1316b341d3b58f7ee7e84beed.jpg: 640x640 1 Gun, 9.4ms
# image 3/196 /content/test/images/0255c5b642987e73_jpg.rf.149bc300c6626152c94570d7c837a2ce.jpg: 640x640 2 Guns, 9.3ms
# image 4/196 /content/test/images/0315e60e498caa4c_jpg.rf.9150790f9da78819fd88c41d72ca86b0.jpg: 640x640 (no detections), 9.3ms
# image 5/196 /content/test/images/039f27ac12c793bb_jpg.rf.65eb442f3dc7816c83b0f6be617be160.jpg: 640x640 (no detections), 9.3ms
# image 6/196 /content/test/images/048cb4cff077fd42_jpg.rf.115c1799ae79af27808cecab7fbf49ab.jpg: 640x640 (no detections), 9.3ms
# ...
